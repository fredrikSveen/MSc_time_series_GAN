# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Resulting single sines for different number of iterations with sequence length 25

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_1_230424_11h01.json', 'r') as file:
    python_obj1 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_1_230424_11h35.json', 'r') as file:
    python_obj2 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_50000_1_230424_15h22.json', 'r') as file:
    python_obj3 = json.load(file)

# %%
df1 = pd.DataFrame(python_obj1[0])
df2 = pd.DataFrame(python_obj2[0])
df3 = pd.DataFrame(python_obj3[0])

df1[1].plot()
df2[1].plot()
df3[1].plot()
plt.legend(["1000 iterations","10 000 iterations", "50 000 iterations"])
plt.show()

# %% [markdown]
# ### Single sines with sequence length 200

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_1_200_240424_10h00.json', 'r') as file:
    dim1_200_1000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_1_200_240424_13h18.json', 'r') as file:
    dim1_200_10000 = json.load(file)

df_dim1_200_1000 = pd.DataFrame(dim1_200_1000[1])
df_dim1_200_10000 = pd.DataFrame(dim1_200_10000[1])

# %%
df_dim1_200_1000[1].iloc[:50].plot()
df_dim1_200_10000[1].iloc[:50].plot()
plt.legend(["1000 iterations","10 000 iterations", "50 000 iterations"])
plt.show()

# %% [markdown]
# ### 2D sines with sequence length 25

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_2_25_240424_08h32.json', 'r') as file:
    dim2_1000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_2_25_240424_09h45.json', 'r') as file:
    dim2_10000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_50000_2_25_240424_16h20.json', 'r') as file:
    dim2_50000 = json.load(file)

df_dim2_1000 = pd.DataFrame(dim2_1000[0])
df_dim2_10000 = pd.DataFrame(dim2_10000[0])
df_dim2_50000 = pd.DataFrame(dim2_50000[0])

# %%
df_dim2_1000.plot(title="Trained with 1000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 1000 iterations'}>

# %%
df_dim2_10000.plot(title="Trained with 10 000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 10 000 iterations'}>

# %%
df_dim2_50000.plot(title="Trained with 50 000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 50 000 iterations'}>

# %% [markdown]
# ### 4D sines with sequence length 25

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_4_25_240424_16h28.json', 'r') as file:
    dim4_1000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_4_25_240424_17h40.json', 'r') as file:
    dim4_10000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_50000_4_25_240424_23h52.json', 'r') as file:
    dim4_50000 = json.load(file)

df_dim4_1000 = pd.DataFrame(dim4_1000[0])
df_dim4_10000 = pd.DataFrame(dim4_10000[0])
df_dim4_50000 = pd.DataFrame(dim4_50000[0])

# %%
df_dim4_1000.plot(title="Trained with 1000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 1000 iterations'}>

# %%
df_dim4_10000.plot(title="Trained with 10 000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 10 000 iterations'}>

# %%
df_dim4_50000.plot(title="Trained with 50 000 iterations")
# Out:
# <Axes: title={'center': 'Trained with 50 000 iterations'}>

# %% [markdown]
# ## 6D sines with sequence length 25

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_6_25_250424_00h00.json', 'r') as file:
    dim6_1000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_6_25_250424_01h20.json', 'r') as file:
    dim6_10000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_50000_6_25_250424_07h20.json', 'r') as file:
    dim6_50000 = json.load(file)

df_dim6_1000 = pd.DataFrame(dim6_1000[0])
df_dim6_10000 = pd.DataFrame(dim6_10000[1])
df_dim6_50000 = pd.DataFrame(dim6_50000[0])

# %%
df_dim6_1000.plot(title="Trained with 1000 iterations", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df_dim6_10000.plot(title="Trained with 10 000 iterations", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df_dim6_50000.plot(title="Trained with 50 000 iterations", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %% [markdown]
# ### 9D sines with sequence length 25

# %%
with open('synt_data/timeGan_generated_sines/syn_sine_1000_9_25_250424_07h27.json', 'r') as file:
    dim9_1000 = json.load(file)
with open('synt_data/timeGan_generated_sines/syn_sine_10000_9_25_250424_08h32.json', 'r') as file:
    dim9_10000 = json.load(file)
# with open('synt_data/timeGan_generated_sines/syn_sine_50000_9_25_250424_07h20.json', 'r') as file:
#     dim9_50000 = json.load(file)

df_dim9_1000 = pd.DataFrame(dim9_1000[0])
df_dim9_10000 = pd.DataFrame(dim9_10000[0])
# df_dim9_50000 = pd.DataFrame(dim9_50000[0])

# %%
df_dim9_1000.plot(title="Trained with 1000 iterations", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df_dim9_10000.plot(title="Trained with 10 000 iterations", subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)
