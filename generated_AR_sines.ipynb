# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import os
from utils import plot_loc_right
# Out:
# 2024-05-24 10:27:49.764880: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-24 10:27:50.152846: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-24 10:27:50.159650: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-24 10:27:53.095226: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with open('synt_data/arima/arima_sine_1_200_090524_15h06.json', 'r') as file:
    arima1 = json.load(file)
with open('synt_data/arima/arima_sine_2_200_090524_15h06.json', 'r') as file:
    arima2 = json.load(file)
with open('synt_data/arima/arima_sine_4_200_090524_15h07.json', 'r') as file:
    arima4 = json.load(file)
with open('synt_data/arima/arima_sine_6_200_090524_15h08.json', 'r') as file:
    arima6 = json.load(file)
with open('synt_data/arima/arima_sine_9_200_090524_15h09.json', 'r') as file:
    arima9 = json.load(file)
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df4 = pd.DataFrame()
df6 = pd.DataFrame()
df9 = pd.DataFrame()
for dim in range(len(arima1)):
    df1[dim] = [i[0] for i in arima1[dim]]
for dim in range(len(arima2)):
    df2[dim] = [i[0] for i in arima2[dim]]
for dim in range(len(arima4)):
    df4[dim] = [i[0] for i in arima4[dim]]
for dim in range(len(arima6)):
    df6[dim] = [i[0] for i in arima6[dim]]
for dim in range(len(arima9)):
    df9[dim] = [i[0] for i in arima9[dim]]

# %%
df1[1].plot(figsize=(12,5))
# Out:
# <Axes: >

# %%
df2.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df4.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df6.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df9.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ## VAR generated sines

# %%
var_9 = pd.DataFrame(np.loadtxt(os.path.join('synt_data', 'VAR', 'var_sine_9_200.csv'), delimiter = ",",skiprows = 1))
plot_loc_right(var_9, subplots=True)
