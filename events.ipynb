# %% [markdown]
# ## Explore events coused by anomalies

# %%
from publicdata import client as c
from datetime import datetime

start = datetime(2000, 1, 1)
events = c.events.list(start_time=start)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 from datetime import datetime
#       4 start = datetime(2000, 1, 1)
# ----> 5 events = c.events.list(start_time=start)
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/_api/events.py:777, in EventsAPI.list(self, start_time, end_time, active_at_time, type, subtype, metadata, asset_ids, asset_external_ids, asset_subtree_ids, asset_subtree_external_ids, data_set_ids, data_set_external_ids, source, created_time, last_updated_time, external_id_prefix, sort, partitions, limit)
#     759 data_set_ids_processed = process_data_set_ids(data_set_ids, data_set_external_ids)
#     761 filter = EventFilter(
#     762     start_time=start_time,
#     763     end_time=end_time,
#    (...)
#     775     subtype=subtype,
#     776 ).dump(camel_case=True)
# --> 777 return self._list(
#     778     list_cls=EventList,
#     779     resource_cls=Event,
#     780     method="POST",
#     781     limit=limit,
#     782     filter=filter,
#     783     partitions=partitions,
#     784     sort=sort,
#     785 )
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/_api_client.py:519, in APIClient._list(self, method, list_cls, resource_cls, resource_path, url_path, limit, filter, other_params, partitions, sort, headers, initial_cursor, advanced_filter, api_subversion)
#     517 resource_path = resource_path or self._RESOURCE_PATH
#     518 items: list[T_CogniteResource] = []
# --> 519 for resource_list in self._list_generator(
#     520     list_cls=list_cls,
#     521     resource_cls=resource_cls,
#     522     resource_path=resource_path,
#     523     url_path=url_path,
#     524     method=method,
#     525     limit=limit,
#     526     chunk_size=self._LIST_LIMIT,
#     527     filter=filter,
#     528     sort=sort,
#     529     other_params=other_params,
#     530     headers=headers,
#     531     initial_cursor=initial_cursor,
#     532     advanced_filter=advanced_filter,
#     533     api_subversion=api_subversion,
#     534 ):
#     535     items.extend(cast(T_CogniteResourceList, resource_list).data)
#     536 return list_cls(items, cognite_client=self._cognite_client)
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/_api_client.py:453, in APIClient._list_generator(self, method, list_cls, resource_cls, resource_path, url_path, limit, chunk_size, filter, sort, other_params, partitions, headers, initial_cursor, advanced_filter, api_subversion)
#     451     if sort is not None:
#     452         body["sort"] = sort
# --> 453     res = self._post(
#     454         url_path=url_path or resource_path + "/list",
#     455         json=body,
#     456         headers=headers,
#     457         api_subversion=api_subversion,
#     458     )
#     459 else:
#     460     raise ValueError(f"_list_generator parameter `method` must be GET or POST, not {method}")
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/_api_client.py:159, in APIClient._post(self, url_path, json, params, headers, api_subversion)
#     151 def _post(
#     152     self,
#     153     url_path: str,
#    (...)
#     157     api_subversion: str | None = None,
#     158 ) -> Response:
# --> 159     return self._do_request(
#     160         "POST",
#     161         url_path,
#     162         json=json,
#     163         headers=headers,
#     164         params=params,
#     165         timeout=self._config.timeout,
#     166         api_subversion=api_subversion,
#     167     )
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/_api_client.py:193, in APIClient._do_request(self, method, url_path, accept, api_subversion, **kwargs)
#     191 if json_payload:
#     192     try:
# --> 193         data = _json.dumps(json_payload, default=json_dump_default, allow_nan=False)
#     194     except ValueError as e:
#     195         # A lot of work to give a more human friendly error message when nans and infs are present:
#     196         msg = "Out of range float values are not JSON compliant"
#
# File ~/anaconda3/lib/python3.9/json/__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File ~/anaconda3/lib/python3.9/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File ~/anaconda3/lib/python3.9/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File ~/time_series_GAN/venv/lib/python3.9/site-packages/cognite/client/utils/_auxiliary.py:124, in json_dump_default(x)
#     122 if hasattr(x, "__dict__"):
#     123     return x.__dict__
# --> 124 raise TypeError(f"Object {x} of type {x.__class__} can't be serialized by the JSON encoder")
#
# TypeError: Object 2000-01-01 00:00:00 of type <class 'datetime.datetime'> can't be serialized by the JSON encoder

# %%
for item in events:
    event_dict = dict(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 for item in events:
# ----> 2     event_dict = dict(item)
#
# TypeError: 'Event' object is not iterable
