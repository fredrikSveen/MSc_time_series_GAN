# %% [markdown]
# # Simple test of the TimeGAN framework
# Using the library ydata-synthetic for a simple implementation process

# %%
#Uncomment to install ydata-synthetic lib
# %pip install ydata-synthetic
# Out:
# Collecting ydata-synthetic
#   Using cached ydata_synthetic-1.3.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting requests<2.31,>=2.30 (from ydata-synthetic)
#   Using cached requests-2.30.0-py3-none-any.whl (62 kB)
# Collecting pandas==2.0.* (from ydata-synthetic)
#   Using cached pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy==1.23.* (from ydata-synthetic)
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Collecting scikit-learn==1.3.* (from ydata-synthetic)
#   Using cached scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting matplotlib==3.7.* (from ydata-synthetic)
#   Using cached matplotlib-3.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting tensorflow==2.12.0 (from ydata-synthetic)
#   Using cached tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
# Collecting tensorflow-probability==0.19.0 (from ydata-synthetic)
#   Using cached tensorflow_probability-0.19.0-py2.py3-none-any.whl (6.7 MB)
# Collecting easydict==1.10 (from ydata-synthetic)
#   Using cached easydict-1.10-py3-none-any.whl
# Collecting pmlb==1.0.* (from ydata-synthetic)
#   Using cached pmlb-1.0.1.post3-py3-none-any.whl (19 kB)
# Collecting tqdm<5.0 (from ydata-synthetic)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting typeguard==4.0.* (from ydata-synthetic)
#   Using cached typeguard-4.0.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting pytest==7.4.* (from ydata-synthetic)
#   Using cached pytest-7.4.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached fonttools-4.47.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from matplotlib==3.7.*->ydata-synthetic) (23.2)
# Collecting pillow>=6.2.0 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.7.*->ydata-synthetic)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from matplotlib==3.7.*->ydata-synthetic) (2.8.2)
# Collecting pytz>=2020.1 (from pandas==2.0.*->ydata-synthetic)
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.0.*->ydata-synthetic)
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyyaml>=5.3.1 (from pmlb==1.0.*->ydata-synthetic)
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting iniconfig (from pytest==7.4.*->ydata-synthetic)
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest==7.4.*->ydata-synthetic)
#   Using cached pluggy-1.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from pytest==7.4.*->ydata-synthetic) (1.2.0)
# Collecting tomli>=1.0.0 (from pytest==7.4.*->ydata-synthetic)
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting scipy>=1.5.0 (from scikit-learn==1.3.*->ydata-synthetic)
#   Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.1.1 (from scikit-learn==1.3.*->ydata-synthetic)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.3.*->ydata-synthetic)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting h5py>=2.9.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting jax>=0.3.15 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached jax-0.4.23-py3-none-any.whl.metadata (24 kB)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Collecting libclang>=13.0.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from tensorflow==2.12.0->ydata-synthetic) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from tensorflow==2.12.0->ydata-synthetic) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Collecting termcolor>=1.1.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from tensorflow==2.12.0->ydata-synthetic) (4.9.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.12.0->ydata-synthetic)
#   Using cached tensorflow_io_gcs_filesystem-0.35.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: decorator in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from tensorflow-probability==0.19.0->ydata-synthetic) (5.1.1)
# Collecting cloudpickle>=1.3 (from tensorflow-probability==0.19.0->ydata-synthetic)
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting dm-tree (from tensorflow-probability==0.19.0->ydata-synthetic)
#   Using cached dm_tree-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
# Collecting charset-normalizer<4,>=2 (from requests<2.31,>=2.30->ydata-synthetic)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<2.31,>=2.30->ydata-synthetic)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<2.31,>=2.30->ydata-synthetic)
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<2.31,>=2.30->ydata-synthetic)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/fredrik/anaconda3/envs/thesis/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.12.0->ydata-synthetic) (0.42.0)
# Collecting ml-dtypes>=0.2.0 (from jax>=0.3.15->tensorflow==2.12.0->ydata-synthetic)
#   Using cached ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached MarkupSafe-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0->ydata-synthetic)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached ydata_synthetic-1.3.2-py2.py3-none-any.whl (86 kB)
# Using cached matplotlib-3.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Using cached pytest-7.4.4-py3-none-any.whl (325 kB)
# Using cached scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
# Using cached typeguard-4.0.1-py3-none-any.whl (33 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.47.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Using cached h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached jax-0.4.23-py3-none-any.whl (1.7 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pluggy-1.4.0-py3-none-any.whl (20 kB)
# Using cached protobuf-4.25.2-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Using cached tensorflow_io_gcs_filesystem-0.35.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Using cached google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
# Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Using cached ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached MarkupSafe-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: pytz, libclang, flatbuffers, easydict, dm-tree, wrapt, urllib3, tzdata, typeguard, tqdm, tomli, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyyaml, pyparsing, pyasn1, protobuf, pluggy, pillow, oauthlib, numpy, MarkupSafe, markdown, kiwisolver, keras, joblib, iniconfig, idna, grpcio, google-pasta, gast, fonttools, cycler, cloudpickle, charset-normalizer, certifi, cachetools, astunparse, absl-py, werkzeug, tensorflow-probability, scipy, rsa, requests, pytest, pyasn1-modules, pandas, opt-einsum, ml-dtypes, h5py, contourpy, scikit-learn, requests-oauthlib, pmlb, matplotlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow, ydata-synthetic
# Successfully installed MarkupSafe-2.1.4 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 cloudpickle-3.0.0 contourpy-1.2.0 cycler-0.12.1 dm-tree-0.1.8 easydict-1.10 flatbuffers-23.5.26 fonttools-4.47.2 gast-0.4.0 google-auth-2.27.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.60.0 h5py-3.10.0 idna-3.6 iniconfig-2.0.0 jax-0.4.23 joblib-1.3.2 keras-2.12.0 kiwisolver-1.4.5 libclang-16.0.6 markdown-3.5.2 matplotlib-3.7.4 ml-dtypes-0.3.2 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 pandas-2.0.3 pillow-10.2.0 pluggy-1.4.0 pmlb-1.0.1.post3 protobuf-4.25.2 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.1 pytest-7.4.4 pytz-2023.3.post1 pyyaml-6.0.1 requests-2.30.0 requests-oauthlib-1.3.1 rsa-4.9 scikit-learn-1.3.2 scipy-1.12.0 tensorboard-2.12.3 tensorboard-data-server-0.7.2 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.35.0 tensorflow-probability-0.19.0 termcolor-2.4.0 threadpoolctl-3.2.0 tomli-2.0.1 tqdm-4.66.1 typeguard-4.0.1 tzdata-2023.4 urllib3-2.1.0 werkzeug-3.0.1 wrapt-1.14.1 ydata-synthetic-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the required libs for the exercise

from os import path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ydata_synthetic.synthesizers import ModelParameters, TrainParameters
from ydata_synthetic.preprocessing.timeseries import processed_stock
from ydata_synthetic.synthesizers.timeseries import TimeSeriesSynthesizer

# %%
# Specific to TimeGANs
seq_len = 24
n_seq = 6
hidden_dim = 24
gamma = 1

noise_dim = 32
dim = 128
batch_size = 128

log_step = 100
learning_rate = 5e-4
# For quick prototyping
# epochs=50000
epochs = 10

gan_args = ModelParameters(
    batch_size=batch_size, lr=learning_rate, noise_dim=noise_dim, layers_dim=dim
)

train_args = TrainParameters(
    epochs=epochs, sequence_length=seq_len, number_sequences=n_seq
)

# %%
data_path = 'data/GOOG.csv'
stock_data = pd.read_csv(data_path)
cols = list(stock_data.columns)
print(stock_data.shape)
print(cols)
stock_data.tail()
# Out:
# (4892, 7)
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
#             Date        Open        High         Low       Close   Adj Close  \
# 4887  2024-01-19  146.304993  148.039993  145.800003  147.970001  147.970001
# 4888  2024-01-22  148.710007  150.014999  147.580002  147.710007  147.710007
# 4889  2024-01-23  147.720001  148.860001  147.190002  148.679993  148.679993
# 4890  2024-01-24  150.289993  151.570007  149.839996  150.350006  150.350006
# 4891  2024-01-25  151.740005  154.759995  151.220001  153.639999  153.639999
#
#         Volume
# 4887  27170900
# 4888  21829200
# 4889  14113600
# 4890  19245000
# 4891  21437100

# %%
col = 'Date'

if path.exists("synthesizer_stock.pkl"):
    synth = TimeSeriesSynthesizer.load("synthesizer_stock.pkl")
else:
    synth = TimeSeriesSynthesizer(modelname="timegan", model_parameters=gan_args)
    synth.fit(stock_data.loc[:, stock_data.columns != col], train_args, num_cols=cols)
    synth.save("synthesizer_stock.pkl")
# Out:
# A DataProcessor is not available for the TimeGAN.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       5 else:
#       6     synth = TimeSeriesSynthesizer(modelname="timegan", model_parameters=gan_args)
# ----> 7     synth.fit(stock_data.loc[:, stock_data.columns != col], train_args, num_cols=cols)
#       8     synth.save("synthesizer_stock.pkl")
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/ydata_synthetic/synthesizers/timeseries/timegan/model.py:69, in TimeGAN.fit(self, data, train_arguments, num_cols, cat_cols)
#      67 self.seq_len = train_arguments.sequence_length
#      68 self.n_seq = train_arguments.number_sequences
# ---> 69 processed_data = real_data_loading(data[self.num_cols].values, seq_len=self.seq_len)
#      70 self.train(data=processed_data, train_steps=train_arguments.epochs)
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/thesis/lib/python3.10/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Date'] not in index"
